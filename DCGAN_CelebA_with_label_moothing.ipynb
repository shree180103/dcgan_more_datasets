# %% [markdown]
# <a href="https://colab.research.google.com/github/shree180103/dcgan_mnist/blob/main/dcgan_with_fid_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
import torchvision
from torchvision.transforms import ToTensor
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets

# %%
torch.cuda.is_available()
# Out:
# True

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
class Discriminator(nn.Module):
  def __init__(self,input_shape:int):
    super().__init__()
    self.conv_layer=nn.Sequential(
        nn.Conv2d(in_channels=input_shape,out_channels=64,kernel_size=4,stride=2,padding=1,bias=False),
        nn.LeakyReLU(0.2,inplace=True),
        nn.Conv2d(in_channels=64,out_channels=128,kernel_size=4,stride=2,padding=1,bias=False),
        nn.BatchNorm2d(128),
        nn.LeakyReLU(0.2,inplace=True),
        nn.Conv2d(in_channels=128,out_channels=256,kernel_size=4,stride=2,padding=1,bias=False),
        nn.BatchNorm2d(256),
        nn.LeakyReLU(0.2,inplace=True),
        nn.Conv2d(in_channels=256,out_channels=512,kernel_size=4,stride=2,padding=1,bias=False),
        nn.BatchNorm2d(512),
        nn.LeakyReLU(0.2,inplace=True),
        nn.Conv2d(in_channels=512,out_channels=1,kernel_size=4,stride=1,padding=0,bias=False),
        nn.Sigmoid()


    )

  def forward(self,x):
    return self.conv_layer(x)

# %%
class Generator(nn.Module):
  def __init__(self,z_dim:int,img_channels):
    super().__init__()
    self.trans_conv_layer=nn.Sequential(
        nn.ConvTranspose2d(in_channels=z_dim,out_channels=512,kernel_size=4,stride=1,padding=0,bias=False),
        nn.BatchNorm2d(512),
        nn.ReLU(True),
        nn.ConvTranspose2d(in_channels=512,out_channels=256,kernel_size=4,stride=2,padding=1,bias=False),
        nn.BatchNorm2d(256),
        nn.ReLU(True),
        nn.ConvTranspose2d(in_channels=256,out_channels=128,kernel_size=4,stride=2,padding=1,bias=False),
        nn.BatchNorm2d(128),
        nn.ReLU(True),
        nn.ConvTranspose2d(in_channels=128,out_channels=64,kernel_size=4,stride=2,padding=1,bias=False),
        nn.BatchNorm2d(64),
        nn.ReLU(True),
        nn.ConvTranspose2d(in_channels=64,out_channels=img_channels,kernel_size=4,stride=2,padding=1,bias=False),
        nn.Tanh()


    )

  def forward(self,x):
    return self.trans_conv_layer(x)

# %%
device="cuda" if torch.cuda.is_available() else "cpu"
# device="cpu"
n_c=3

gen=Generator(z_dim=100,img_channels=n_c).to(device)
gen.apply(weights_init)

disc=Discriminator(input_shape=n_c).to(device)
disc.apply(weights_init)
# Out:
# Discriminator(
#   (conv_layer): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %%
device
# Out:
# 'cuda'

# %%
# training params
batch_size=128
lr=0.0002
z_dim=100
img_size=64
n_c=3

transform=transforms.Compose(transforms=[transforms.ToTensor(),
                                         transforms.Resize((64,64)),
                                         transforms.CenterCrop(img_size),
                                         transforms.Normalize([0.5 for _ in range(n_c)],[0.5 for _ in range(n_c)])])
dataset=datasets.ImageFolder(root="celeb_hq",transform=transform)
data_loader=DataLoader(dataset=dataset,batch_size=batch_size,shuffle=True)

# %%
image,label=next(iter(data_loader))
import matplotlib.pyplot as plt
plt.imshow((image[0]*0.5+0.5).permute(1,2,0))
plt.show()

# %%
loss_fn=nn.BCELoss()
optimizer_disc=torch.optim.Adam(params=disc.parameters(),lr=lr,betas=(0.5,0.999))
optimizer_gen=torch.optim.Adam(params=gen.parameters(),lr=lr,betas=(0.5,0.999))

# %%
writer_fake=SummaryWriter("logs/GAN_MNIST/fake")

writer_real=SummaryWriter("logs/GAN_MNIST/real")

step = 0

fixed_noise = torch.randn(size=(64,z_dim,1,1))

# %%
# z=torch.rand(size=(1,100,1,1))
# z.shape

# %%
# img,label=next(iter(data_loader))
# img.shape

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in c:\users\shree\anaconda3\envs\deepenv1\lib\site-packages (1.8.0)

# %%
from torchinfo import summary

summary(disc,input_size=[1,3,64,64])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Discriminator                            [1, 1, 1, 1]              --
# ├─Sequential: 1-1                        [1, 1, 1, 1]              --
# │    └─Conv2d: 2-1                       [1, 64, 32, 32]           3,072
# │    └─LeakyReLU: 2-2                    [1, 64, 32, 32]           --
# │    └─Conv2d: 2-3                       [1, 128, 16, 16]          131,072
# │    └─BatchNorm2d: 2-4                  [1, 128, 16, 16]          256
# │    └─LeakyReLU: 2-5                    [1, 128, 16, 16]          --
# │    └─Conv2d: 2-6                       [1, 256, 8, 8]            524,288
# │    └─BatchNorm2d: 2-7                  [1, 256, 8, 8]            512
# │    └─LeakyReLU: 2-8                    [1, 256, 8, 8]            --
# │    └─Conv2d: 2-9                       [1, 512, 4, 4]            2,097,152
# │    └─BatchNorm2d: 2-10                 [1, 512, 4, 4]            1,024
# │    └─LeakyReLU: 2-11                   [1, 512, 4, 4]            --
# │    └─Conv2d: 2-12                      [1, 1, 1, 1]              8,192
# │    └─Sigmoid: 2-13                     [1, 1, 1, 1]              --
# ==========================================================================================
# Total params: 2,765,568
# Trainable params: 2,765,568
# Non-trainable params: 0
# Total mult-adds (M): 103.82
# ==========================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 1.44
# Params size (MB): 11.06
# Estimated Total Size (MB): 12.55
# ==========================================================================================

# %%
# disc.eval()
# with torch.inference_mode():
#   print(disc(torch.rand(size=(1,1,64,64)).to('cuda')).shape)

# %%
# disc.eval()
# with torch.inference_mode():
#   print(disc(torch.rand(size=(1,1,64,64)).to('cuda')).shape)

# %%
summary(gen,input_size=[1,100,1,1])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Generator                                [1, 3, 64, 64]            --
# ├─Sequential: 1-1                        [1, 3, 64, 64]            --
# │    └─ConvTranspose2d: 2-1              [1, 512, 4, 4]            819,200
# │    └─BatchNorm2d: 2-2                  [1, 512, 4, 4]            1,024
# │    └─ReLU: 2-3                         [1, 512, 4, 4]            --
# │    └─ConvTranspose2d: 2-4              [1, 256, 8, 8]            2,097,152
# │    └─BatchNorm2d: 2-5                  [1, 256, 8, 8]            512
# │    └─ReLU: 2-6                         [1, 256, 8, 8]            --
# │    └─ConvTranspose2d: 2-7              [1, 128, 16, 16]          524,288
# │    └─BatchNorm2d: 2-8                  [1, 128, 16, 16]          256
# │    └─ReLU: 2-9                         [1, 128, 16, 16]          --
# │    └─ConvTranspose2d: 2-10             [1, 64, 32, 32]           131,072
# │    └─BatchNorm2d: 2-11                 [1, 64, 32, 32]           128
# │    └─ReLU: 2-12                        [1, 64, 32, 32]           --
# │    └─ConvTranspose2d: 2-13             [1, 3, 64, 64]            3,072
# │    └─Tanh: 2-14                        [1, 3, 64, 64]            --
# ==========================================================================================
# Total params: 3,576,704
# Trainable params: 3,576,704
# Non-trainable params: 0
# Total mult-adds (M): 428.35
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.06
# Params size (MB): 14.31
# Estimated Total Size (MB): 16.37
# ==========================================================================================

# %%
# gen.eval()
# with torch.inference_mode():
#   print(gen(z.to('cuda')).shape)

# %%
import math
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision.models import inception_v3
from torchvision.models import Inception_V3_Weights
import scipy
import numpy as np

# %%
from tqdm.auto import tqdm

epochs=200
LOSS_D=[]
LOSS_G=[]
fid_scores=[]

for epoch in tqdm(range(epochs)):
  for batch_idx,(x,_) in enumerate(data_loader):
    z=torch.randn(size=(batch_size,100,1,1),device=device)

    ## traing the discriminator

    disc.zero_grad()
    disc_real=disc(x.to(device)).reshape(-1)
    loss_disc_real=loss_fn(disc_real,torch.full_like(disc_real,0.9))
    loss_disc_real.backward()


    fake=gen(z.to(device))

    
    disc_fake=disc(fake.detach().to(device)).reshape(-1)
    loss_disc_fake=loss_fn(disc_fake,torch.zeros_like(disc_fake))
    loss_disc_fake.backward()

    loss_disc=loss_disc_fake+loss_disc_real
    LOSS_D.append(loss_disc.item())

    optimizer_disc.step()

    #training generator
    gen.zero_grad()

    fool_logits=disc(fake.to(device)).reshape(-1)
    loss_gen=loss_fn(fool_logits,torch.ones_like(fool_logits))
    LOSS_G.append(loss_gen.item())

    loss_gen.backward()

    optimizer_gen.step()

    if batch_idx== 0:
           
            print(
                f"Epoch [{epoch}/{epochs}] Batch {batch_idx}/{len(data_loader)} \
                  Loss D: {loss_disc:.4f}, loss G: {loss_gen:.4f}"
            )

            with torch.no_grad():
                fake = gen(fixed_noise.to(device)).detach()
                # take out (up to) 32 examples
                img_grid_real = torchvision.utils.make_grid(x[:32], normalize=True)
                img_grid_fake = torchvision.utils.make_grid(fake[:32], normalize=True)

                writer_real.add_image("Real", img_grid_real, global_step=step)
                writer_fake.add_image("Fake", img_grid_fake, global_step=step)

            step += 1
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch [0/200] Batch 0/235                   Loss D: 1.7306, loss G: 3.7899
# Epoch [1/200] Batch 0/235                   Loss D: 0.8223, loss G: 5.5501
# Epoch [2/200] Batch 0/235                   Loss D: 1.0613, loss G: 6.5903
# Epoch [3/200] Batch 0/235                   Loss D: 1.0381, loss G: 6.9198
# Epoch [4/200] Batch 0/235                   Loss D: 0.7716, loss G: 4.3437
# Epoch [5/200] Batch 0/235                   Loss D: 0.7212, loss G: 3.3579
# Epoch [6/200] Batch 0/235                   Loss D: 0.7528, loss G: 3.5098
# Epoch [7/200] Batch 0/235                   Loss D: 0.7983, loss G: 4.5024
# Epoch [8/200] Batch 0/235                   Loss D: 0.7194, loss G: 3.0461
# Epoch [9/200] Batch 0/235                   Loss D: 0.8793, loss G: 4.9356
# Epoch [10/200] Batch 0/235                   Loss D: 1.1041, loss G: 5.7700
# Epoch [11/200] Batch 0/235                   Loss D: 0.6175, loss G: 4.2362
# Epoch [12/200] Batch 0/235                   Loss D: 0.8433, loss G: 2.4283
# Epoch [13/200] Batch 0/235                   Loss D: 0.6745, loss G: 2.5683
# Epoch [14/200] Batch 0/235                   Loss D: 0.8145, loss G: 1.8620
# Epoch [15/200] Batch 0/235                   Loss D: 0.8870, loss G: 3.4485
# Epoch [16/200] Batch 0/235                   Loss D: 1.0469, loss G: 4.1838
# Epoch [17/200] Batch 0/235                   Loss D: 1.0403, loss G: 3.9688
# Epoch [18/200] Batch 0/235                   Loss D: 1.0560, loss G: 4.9794
# Epoch [19/200] Batch 0/235                   Loss D: 0.8297, loss G: 2.7166
# Epoch [20/200] Batch 0/235                   Loss D: 0.9692, loss G: 4.4047
# Epoch [21/200] Batch 0/235                   Loss D: 0.7446, loss G: 3.3533
# Epoch [22/200] Batch 0/235                   Loss D: 1.1892, loss G: 4.2173
# Epoch [23/200] Batch 0/235                   Loss D: 1.2540, loss G: 4.4413
# Epoch [24/200] Batch 0/235                   Loss D: 1.0355, loss G: 3.8131
# Epoch [25/200] Batch 0/235                   Loss D: 0.9236, loss G: 1.0780
# Epoch [26/200] Batch 0/235                   Loss D: 0.8231, loss G: 2.4445
# Epoch [27/200] Batch 0/235                   Loss D: 0.7074, loss G: 2.0251
# Epoch [28/200] Batch 0/235                   Loss D: 0.8142, loss G: 1.9353
# Epoch [29/200] Batch 0/235                   Loss D: 0.8580, loss G: 2.9548
# Epoch [30/200] Batch 0/235                   Loss D: 0.8905, loss G: 3.7255
# Epoch [31/200] Batch 0/235                   Loss D: 0.9472, loss G: 3.9222
# Epoch [32/200] Batch 0/235                   Loss D: 0.7972, loss G: 1.5965
# Epoch [33/200] Batch 0/235                   Loss D: 0.7382, loss G: 2.3275
# Epoch [34/200] Batch 0/235                   Loss D: 0.9245, loss G: 3.7097
# Epoch [35/200] Batch 0/235                   Loss D: 0.8508, loss G: 1.7698
# Epoch [36/200] Batch 0/235                   Loss D: 1.2180, loss G: 4.7642
# Epoch [37/200] Batch 0/235                   Loss D: 0.7082, loss G: 2.4425
# Epoch [38/200] Batch 0/235                   Loss D: 0.6847, loss G: 2.4945
# Epoch [39/200] Batch 0/235                   Loss D: 0.8504, loss G: 3.6294
# Epoch [40/200] Batch 0/235                   Loss D: 1.0454, loss G: 4.1104
# Epoch [41/200] Batch 0/235                   Loss D: 0.8681, loss G: 1.5364
# Epoch [42/200] Batch 0/235                   Loss D: 0.6437, loss G: 2.0039
# Epoch [43/200] Batch 0/235                   Loss D: 0.7127, loss G: 3.1932
# Epoch [44/200] Batch 0/235                   Loss D: 0.6488, loss G: 2.2565
# Epoch [45/200] Batch 0/235                   Loss D: 0.7602, loss G: 1.7553
# Epoch [46/200] Batch 0/235                   Loss D: 0.7926, loss G: 3.6968
# Epoch [47/200] Batch 0/235                   Loss D: 1.0369, loss G: 4.8741
# Epoch [48/200] Batch 0/235                   Loss D: 0.8155, loss G: 3.7649
# Epoch [49/200] Batch 0/235                   Loss D: 0.6672, loss G: 2.7781
# Epoch [50/200] Batch 0/235                   Loss D: 0.5426, loss G: 3.3882
# Epoch [51/200] Batch 0/235                   Loss D: 0.6046, loss G: 2.5923
# Epoch [52/200] Batch 0/235                   Loss D: 0.7519, loss G: 2.7196
# Epoch [53/200] Batch 0/235                   Loss D: 0.6495, loss G: 2.6187
# Epoch [54/200] Batch 0/235                   Loss D: 0.5470, loss G: 2.6920
# Epoch [55/200] Batch 0/235                   Loss D: 0.5245, loss G: 3.1889
# Epoch [56/200] Batch 0/235                   Loss D: 1.2513, loss G: 1.6082
# Epoch [57/200] Batch 0/235                   Loss D: 0.8221, loss G: 4.8333
# Epoch [58/200] Batch 0/235                   Loss D: 0.5895, loss G: 4.1396
# Epoch [59/200] Batch 0/235                   Loss D: 0.4991, loss G: 3.1627
# Epoch [60/200] Batch 0/235                   Loss D: 0.7951, loss G: 1.3974
# Epoch [61/200] Batch 0/235                   Loss D: 0.4576, loss G: 3.6054
# Epoch [62/200] Batch 0/235                   Loss D: 0.4590, loss G: 3.4965
# Epoch [63/200] Batch 0/235                   Loss D: 0.7907, loss G: 4.5003
# Epoch [64/200] Batch 0/235                   Loss D: 0.4839, loss G: 3.5038
# Epoch [65/200] Batch 0/235                   Loss D: 0.7365, loss G: 2.2857
# Epoch [66/200] Batch 0/235                   Loss D: 0.5250, loss G: 2.9058
# Epoch [67/200] Batch 0/235                   Loss D: 0.5291, loss G: 4.1689
# Epoch [68/200] Batch 0/235                   Loss D: 0.4846, loss G: 3.2380
# Epoch [69/200] Batch 0/235                   Loss D: 0.7910, loss G: 4.7134
# Epoch [70/200] Batch 0/235                   Loss D: 0.5765, loss G: 3.9997
# Epoch [71/200] Batch 0/235                   Loss D: 2.0813, loss G: 4.5235
# Epoch [72/200] Batch 0/235                   Loss D: 0.4719, loss G: 3.3178
# Epoch [73/200] Batch 0/235                   Loss D: 0.5697, loss G: 4.2895
# Epoch [74/200] Batch 0/235                   Loss D: 0.7742, loss G: 4.7565
# Epoch [75/200] Batch 0/235                   Loss D: 0.5599, loss G: 4.8272
# Epoch [76/200] Batch 0/235                   Loss D: 0.4707, loss G: 4.5485
# Epoch [77/200] Batch 0/235                   Loss D: 0.4868, loss G: 3.2861
# Epoch [78/200] Batch 0/235                   Loss D: 0.6410, loss G: 4.4518
# Epoch [79/200] Batch 0/235                   Loss D: 0.4503, loss G: 2.9560
# Epoch [80/200] Batch 0/235                   Loss D: 0.4787, loss G: 3.9136
# Epoch [81/200] Batch 0/235                   Loss D: 0.7335, loss G: 4.1293
# Epoch [82/200] Batch 0/235                   Loss D: 0.4485, loss G: 3.4793
# Epoch [83/200] Batch 0/235                   Loss D: 1.2290, loss G: 0.9242
# Epoch [84/200] Batch 0/235                   Loss D: 1.7028, loss G: 6.4805
# Epoch [85/200] Batch 0/235                   Loss D: 0.4423, loss G: 4.4225
# Epoch [86/200] Batch 0/235                   Loss D: 0.8563, loss G: 4.8005
# Epoch [87/200] Batch 0/235                   Loss D: 0.5557, loss G: 5.0896
# Epoch [88/200] Batch 0/235                   Loss D: 0.4297, loss G: 3.9620
# Epoch [89/200] Batch 0/235                   Loss D: 0.4796, loss G: 4.7979
# Epoch [90/200] Batch 0/235                   Loss D: 0.5103, loss G: 4.7670
# Epoch [91/200] Batch 0/235                   Loss D: 0.4231, loss G: 3.7728
# Epoch [92/200] Batch 0/235                   Loss D: 1.4139, loss G: 6.4636
# Epoch [93/200] Batch 0/235                   Loss D: 0.5068, loss G: 4.5555
# Epoch [94/200] Batch 0/235                   Loss D: 1.5875, loss G: 0.9972
# Epoch [95/200] Batch 0/235                   Loss D: 0.5413, loss G: 3.0453
# Epoch [96/200] Batch 0/235                   Loss D: 0.3933, loss G: 4.0910
# Epoch [97/200] Batch 0/235                   Loss D: 0.5006, loss G: 3.0404
# Epoch [98/200] Batch 0/235                   Loss D: 0.4658, loss G: 3.6270
# Epoch [99/200] Batch 0/235                   Loss D: 0.4900, loss G: 3.1365
# Epoch [100/200] Batch 0/235                   Loss D: 0.4506, loss G: 3.2121
# Epoch [101/200] Batch 0/235                   Loss D: 0.4194, loss G: 4.4608
# Epoch [102/200] Batch 0/235                   Loss D: 0.4374, loss G: 4.1712
# Epoch [103/200] Batch 0/235                   Loss D: 0.4663, loss G: 4.3911
# Epoch [104/200] Batch 0/235                   Loss D: 0.4144, loss G: 5.2692
# Epoch [105/200] Batch 0/235                   Loss D: 0.4303, loss G: 4.4910
# Epoch [106/200] Batch 0/235                   Loss D: 0.5408, loss G: 4.9310
# Epoch [107/200] Batch 0/235                   Loss D: 1.6020, loss G: 1.3739
# Epoch [108/200] Batch 0/235                   Loss D: 0.4162, loss G: 4.3817
# Epoch [109/200] Batch 0/235                   Loss D: 0.4133, loss G: 3.6811
# Epoch [110/200] Batch 0/235                   Loss D: 0.5340, loss G: 4.8599
# Epoch [111/200] Batch 0/235                   Loss D: 0.4565, loss G: 4.3941
# Epoch [112/200] Batch 0/235                   Loss D: 0.4195, loss G: 3.9826
# Epoch [113/200] Batch 0/235                   Loss D: 0.5164, loss G: 3.4167
# Epoch [114/200] Batch 0/235                   Loss D: 0.4081, loss G: 4.2113
# Epoch [115/200] Batch 0/235                   Loss D: 0.4010, loss G: 3.9333
# Epoch [116/200] Batch 0/235                   Loss D: 0.7763, loss G: 5.4991
# Epoch [117/200] Batch 0/235                   Loss D: 0.4745, loss G: 4.9131
# Epoch [118/200] Batch 0/235                   Loss D: 0.3922, loss G: 4.4633
# Epoch [119/200] Batch 0/235                   Loss D: 0.4955, loss G: 3.2922
# Epoch [120/200] Batch 0/235                   Loss D: 0.4026, loss G: 4.1910
# Epoch [121/200] Batch 0/235                   Loss D: 0.3977, loss G: 4.5824
# Epoch [122/200] Batch 0/235                   Loss D: 0.4292, loss G: 4.2535
# Epoch [123/200] Batch 0/235                   Loss D: 0.4157, loss G: 3.7864
# Epoch [124/200] Batch 0/235                   Loss D: 0.3818, loss G: 5.3591
# Epoch [125/200] Batch 0/235                   Loss D: 1.4153, loss G: 6.7517
# Epoch [126/200] Batch 0/235                   Loss D: 0.4760, loss G: 4.6976
# Epoch [127/200] Batch 0/235                   Loss D: 0.4303, loss G: 4.1032
# Epoch [128/200] Batch 0/235                   Loss D: 0.4324, loss G: 4.0005
# Epoch [129/200] Batch 0/235                   Loss D: 0.3952, loss G: 3.8133
# Epoch [130/200] Batch 0/235                   Loss D: 0.7864, loss G: 5.9708
# Epoch [131/200] Batch 0/235                   Loss D: 0.4542, loss G: 3.7135
# Epoch [132/200] Batch 0/235                   Loss D: 0.4152, loss G: 4.4316
# Epoch [133/200] Batch 0/235                   Loss D: 0.5032, loss G: 5.2115
# Epoch [134/200] Batch 0/235                   Loss D: 0.4772, loss G: 2.4945
# Epoch [135/200] Batch 0/235                   Loss D: 0.4018, loss G: 4.2677
# Epoch [136/200] Batch 0/235                   Loss D: 0.9990, loss G: 1.1587
# Epoch [137/200] Batch 0/235                   Loss D: 0.4433, loss G: 4.7515
# Epoch [138/200] Batch 0/235                   Loss D: 0.4032, loss G: 4.5289
# Epoch [139/200] Batch 0/235                   Loss D: 0.4321, loss G: 4.9706
# Epoch [140/200] Batch 0/235                   Loss D: 0.3965, loss G: 4.3272
# Epoch [141/200] Batch 0/235                   Loss D: 0.4762, loss G: 5.3831
# Epoch [142/200] Batch 0/235                   Loss D: 0.4967, loss G: 5.6188
# Epoch [143/200] Batch 0/235                   Loss D: 0.5056, loss G: 3.6569
# Epoch [144/200] Batch 0/235                   Loss D: 0.5412, loss G: 5.1122
# Epoch [145/200] Batch 0/235                   Loss D: 0.5312, loss G: 5.1589
# Epoch [146/200] Batch 0/235                   Loss D: 0.3739, loss G: 5.2574
# Epoch [147/200] Batch 0/235                   Loss D: 0.3937, loss G: 4.6310
# Epoch [148/200] Batch 0/235                   Loss D: 0.4080, loss G: 4.9789
# Epoch [149/200] Batch 0/235                   Loss D: 0.3780, loss G: 4.8019
# Epoch [150/200] Batch 0/235                   Loss D: 0.4368, loss G: 4.3290
# Epoch [151/200] Batch 0/235                   Loss D: 0.4066, loss G: 4.4824
# Epoch [152/200] Batch 0/235                   Loss D: 0.3800, loss G: 4.8630
# Epoch [153/200] Batch 0/235                   Loss D: 1.3529, loss G: 7.4204
# Epoch [154/200] Batch 0/235                   Loss D: 0.3937, loss G: 5.4946
# Epoch [155/200] Batch 0/235                   Loss D: 0.3701, loss G: 4.6080
# Epoch [156/200] Batch 0/235                   Loss D: 0.4054, loss G: 4.7704
# Epoch [157/200] Batch 0/235                   Loss D: 0.5362, loss G: 4.8801
# Epoch [158/200] Batch 0/235                   Loss D: 0.8729, loss G: 6.4831
# Epoch [159/200] Batch 0/235                   Loss D: 0.4045, loss G: 4.9563
# Epoch [160/200] Batch 0/235                   Loss D: 0.3791, loss G: 5.3694
# Epoch [161/200] Batch 0/235                   Loss D: 0.4028, loss G: 4.5619
# Epoch [162/200] Batch 0/235                   Loss D: 2.9794, loss G: 4.2736
# Epoch [163/200] Batch 0/235                   Loss D: 0.4071, loss G: 4.9081
# Epoch [164/200] Batch 0/235                   Loss D: 0.3824, loss G: 4.9922
# Epoch [165/200] Batch 0/235                   Loss D: 0.4126, loss G: 4.2040
# Epoch [166/200] Batch 0/235                   Loss D: 0.5639, loss G: 5.0255
# Epoch [167/200] Batch 0/235                   Loss D: 0.4108, loss G: 4.4867
# Epoch [168/200] Batch 0/235                   Loss D: 0.3697, loss G: 4.5559
# Epoch [169/200] Batch 0/235                   Loss D: 0.4116, loss G: 4.0327
# Epoch [170/200] Batch 0/235                   Loss D: 0.4126, loss G: 4.3202
# Epoch [171/200] Batch 0/235                   Loss D: 0.4516, loss G: 5.0568
# Epoch [172/200] Batch 0/235                   Loss D: 0.8803, loss G: 1.3900
# Epoch [173/200] Batch 0/235                   Loss D: 0.4635, loss G: 4.0671
# Epoch [174/200] Batch 0/235                   Loss D: 0.3623, loss G: 4.9352
# Epoch [175/200] Batch 0/235                   Loss D: 0.4241, loss G: 4.9432
# Epoch [176/200] Batch 0/235                   Loss D: 0.4120, loss G: 4.6364
# Epoch [177/200] Batch 0/235                   Loss D: 0.5612, loss G: 5.7884
# Epoch [178/200] Batch 0/235                   Loss D: 0.3761, loss G: 5.0124
# Epoch [179/200] Batch 0/235                   Loss D: 0.3826, loss G: 5.4299
# Epoch [180/200] Batch 0/235                   Loss D: 0.3754, loss G: 4.9981
# Epoch [181/200] Batch 0/235                   Loss D: 0.4702, loss G: 4.9012
# Epoch [182/200] Batch 0/235                   Loss D: 1.8755, loss G: 1.7365
# Epoch [183/200] Batch 0/235                   Loss D: 0.3993, loss G: 4.8218
# Epoch [184/200] Batch 0/235                   Loss D: 0.3902, loss G: 4.5076
# Epoch [185/200] Batch 0/235                   Loss D: 0.4010, loss G: 4.6373
# Epoch [186/200] Batch 0/235                   Loss D: 0.3803, loss G: 5.1918
# Epoch [187/200] Batch 0/235                   Loss D: 0.4520, loss G: 4.8033
# Epoch [188/200] Batch 0/235                   Loss D: 0.3754, loss G: 5.1405
# Epoch [189/200] Batch 0/235                   Loss D: 0.3822, loss G: 4.4969
# Epoch [190/200] Batch 0/235                   Loss D: 0.4708, loss G: 3.7164
# Epoch [191/200] Batch 0/235                   Loss D: 0.5388, loss G: 5.3567
# Epoch [192/200] Batch 0/235                   Loss D: 0.3950, loss G: 4.9358
# Epoch [193/200] Batch 0/235                   Loss D: 0.4372, loss G: 4.9174
# Epoch [194/200] Batch 0/235                   Loss D: 0.3812, loss G: 5.1962
# Epoch [195/200] Batch 0/235                   Loss D: 0.4968, loss G: 4.1078
# Epoch [196/200] Batch 0/235                   Loss D: 0.6245, loss G: 5.3026
# Epoch [197/200] Batch 0/235                   Loss D: 0.4235, loss G: 4.2747
# Epoch [198/200] Batch 0/235                   Loss D: 0.3753, loss G: 4.8098
# Epoch [199/200] Batch 0/235                   Loss D: 0.4088, loss G: 4.7438

# %%
noise=torch.rand(size=(batch_size,z_dim,1,1)).to(device)
gen_img=gen(noise)

# %%
with torch.inference_mode():
  for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow((gen_img[i]*0.5+0.5).permute(1,2,0).cpu())
    plt.axis(False)

# %%
plt.plot(LOSS_D,label="Discriminator Loss")
plt.plot(LOSS_G,label="Generator Loss")
plt.legend()
plt.show()

# %%
class PartialInceptionNetwork(nn.Module):
  def __init__(self):
    super(PartialInceptionNetwork, self).__init__()
    self.inception_model = inception_v3(weights=Inception_V3_Weights.DEFAULT)  #initializing pretrsined model
    self.inception_model.Mixed_7c.register_forward_hook(self.output_hook)
    self.output = None

  def output_hook(self, module, input, output):
    self.mixed_7c_output = output

  def forward(self, x):
    assert x.shape[1:] == (3, 299, 299), "Input shape should be (batch_size, 3, 299, 299)"
    self.inception_model(x)
    activations = self.mixed_7c_output
    activations = F.adaptive_avg_pool2d(activations, (1, 1))
    activations = activations.view(x.shape[0],2048)
    return activations

net=PartialInceptionNetwork().to(device)

def fid_score(real_images, gen_images,batch_size):
  real_activations = []
  gen_activations = []
  num_steps=int(math.ceil(float(len(real_images))/float(batch_size)))
  for i in range(num_steps):
    s = i * batch_size
    e=(1+i) * batch_size

    mini_real_batch=real_images[s:e]
    mini_gen_batch=gen_images[s:e]

    batch_real=Variable(mini_real_batch).to(device)
    batch_gen=Variable(mini_gen_batch).to(device)

  features_real=net(batch_real)
  features_gen=net(batch_gen)

  real_activations.append(features_real)
  gen_activations.append(features_gen)

  features_real=torch.cat(real_activations,0)
  features_gen=torch.cat(gen_activations,0)

  xr=features_real.cpu().detach().numpy()
  xg=features_gen.cpu().detach().numpy()

  u1=np.mean(xr,axis=0)
  u2=np.mean(xg,axis=0)
  s1=np.cov(xr,rowvar=False)
  s2=np.cov(xg,rowvar=False)

  diff=u1-u2
  diff_squared=diff.dot(diff)

  prod=np.dot(s1,s2)

  sqrt_prod,_=scipy.linalg.sqrtm(prod,disp=False)

  if np.iscomplexobj(sqrt_prod):
      sqrt_prod=sqrt_prod.real

  prod_tr=np.trace(sqrt_prod)

  fid_score=diff_squared+np.trace(s1)+np.trace(s2)-2*prod_tr

  return fid_score

# %%
x,label=next(iter(data_loader))
x=x[0:32]
gen_img=gen_img[0:32]
gen_images=gen_img.view(-1,1,64,64)
gen_images=gen_images.repeat(1,3,1,1)
gen_res_images=F.interpolate(gen_images,size=(299,299))
real_images = x.view(-1, 1, 64, 64) # Reshape real_images similar to gen_images
real_images = real_images.repeat(1, 3, 1, 1) # Repeat channels for real_images
real_images = F.interpolate(real_images, size=(299, 299)) # Resize 
net.eval()  # Set the model to evaluation mode
fid = fid_score(real_images, gen_res_images,32)
print(fid)
# Out:
# 93.03764001963151

# %%
import torch
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

# Function to get real images from your dataset
def get_real_images(data_loader):
    real_images,_ = next(iter(data_loader))
    return real_images[:32]

# Function to generate fake images from the generator
def generate_fake_images(gen, num_images, noise_dim):
    noise = torch.randn(num_images, noise_dim).to(device)  # Shape: [num_images, noise_dim]
    noise = noise.view(num_images, noise_dim, 1, 1)  # Reshape to [num_images, noise_dim, 1, 1]
    with torch.no_grad():
        fake_images = gen(noise)  # Pass reshaped noise to the generator
    return fake_images

# Display images
def show_images(real_images, fake_images):


    

    # Create a grid of images
    real_grid = make_grid(real_images, nrow=8)
    fake_grid = make_grid(fake_images, nrow=8)

    plt.figure(figsize=(12, 6))

    # Plot real images
    plt.subplot(1, 2, 1)
    plt.title("Real Images")
    plt.imshow((real_grid*0.5+0.5).permute(1, 2, 0))
    plt.axis('off')

    # Plot fake images
    plt.subplot(1, 2, 2)
    plt.title("Fake Images")
    plt.imshow((fake_grid*0.5+0.5).cpu().permute(1, 2, 0))
    plt.axis('off')

    plt.show()

# Hyperparameters
batch_size = 32
noise_dim = 100

# Assume you have a data loader for real images
# Example: data_loader = DataLoader(your_dataset, batch_size=batch_size, shuffle=True)

# Get real images
real_images = get_real_images(data_loader)

# Generate fake images
num_images = batch_size  # Same as the batch size for consistency
fake_images = generate_fake_images(gen, num_images, noise_dim)

# Show images
show_images(real_images, fake_images)
